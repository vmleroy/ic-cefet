# %% [markdown]
# # Exercicio 1
# * Arthur Severo
# * Victor Le Roy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **1. Coletando os dados**

# %%
df = pd.read_csv('./data/data1.txt', sep=',', header=None, names=['City Pop.', 'Profit'])
city_pop = df["City Pop."].values
profit = df["Profit"].values

print(df)
# Out:
#     City Pop.    Profit
# 0      6.1101  17.59200
# 1      5.5277   9.13020
# 2      8.5186  13.66200
# 3      7.0032  11.85400
# 4      5.8598   6.82330
# ..        ...       ...
# 92     5.8707   7.20290
# 93     5.3054   1.98690
# 94     8.2934   0.14454
# 95    13.3940   9.05510
# 96     5.4369   0.61705
#
# [97 rows x 2 columns]

# %% [markdown]
# **2. Plotando gráfico**

# %%
plt.scatter(city_pop, profit, marker='x', c='r')
plt.xlabel('City Population')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# **3. Gradiente descendente**

# %%
theta_0, theta_1 = 1, 1
alpha = 0.01
epochs = 1500
m = len(city_pop)

h_per_epoch = []
loss_error_per_epoch = []

for epoch in range(epochs):
    h = theta_0 + theta_1 * city_pop
    theta_0 = theta_0 - alpha * (1 / m) * np.sum(h - profit)
    theta_1 = theta_1 - alpha * (1 / m) * np.sum((h - profit) * city_pop)
    h_per_epoch.append(h)
    loss_error_per_epoch.append((1 / (2 * m)) * np.sum(np.square(h - profit)))

h_per_epoch.append(theta_0 + theta_1 * city_pop)

# %% [markdown]
# **4. Plotando o resultado**

# %% [markdown]
# * Alteração na regressão linear

# %%
for index, h in enumerate(h_per_epoch):
    if index % 200 == 0 and index != (len(h_per_epoch) - 1):
        plt.plot(city_pop, h, c='r', alpha=index/epochs)
plt.plot(city_pop, h_per_epoch[-1], c='b', alpha=1, label='Linear Regression')

# %% [markdown]
# * Resultado final

# %%
plt.scatter(city_pop, profit, marker='x', c='r')
plt.plot(city_pop, h_per_epoch[-1], c='b', alpha=1, label='Linear Regression')
plt.xlabel('City Population')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# * Erro

# %%
print(f"Erro final: {loss_error_per_epoch[-1]}")
plt.plot(loss_error_per_epoch, c='g', alpha=1, label='Loss Error')
plt.xlabel('Epochs')
plt.ylabel('Loss Error')
# Out:
# Erro final: 4.486619891131372
# Text(0, 0.5, 'Loss Error')
