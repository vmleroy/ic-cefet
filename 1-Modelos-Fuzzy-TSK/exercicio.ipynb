# %% [markdown]
# # Atividade 1 - Modelos Fuzzy TSK (exemplo 3 e 4 dados em sala)
#
# * Alunos:
#   * Arthur Severo
#   * Victor Le Roy

# %%
import fuzzy_tsk as ftsk

ftsk.example_3()

# %%
import fuzzy_tsk as ftsk

ftsk.example_4()
# Out:
# w1 = 0.5 - 0.25*x
# w2 = 0.25*x + 0.5
#
# y1 = -2*x
# y2 = 2*x
#
# y = -2.0*x*(0.5 - 0.25*x) + 2.0*x*(0.25*x + 0.5)
# y = x**2
